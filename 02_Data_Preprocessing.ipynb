# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("medical_data.csv")

# %%
print (df)
# Out:
#       Age  Gender  Systolic_BP  Cholesterol  Blood_Sugar   BMI  Smoking  \
# 0      58       1          165          236           92  31.9        1
# 1      71       0           91          257          240  29.9        1
# 2      48       1          164          324           71  19.2        1
# 3      34       1          117          212          235  34.3        1
# 4      62       1          171          267          226  21.8        0
# ...   ...     ...          ...          ...          ...   ...      ...
# 4995   52       0          108          315          217  24.6        0
# 4996   79       0          111          303          240  23.7        0
# 4997   46       1          122          183          188  37.6        0
# 4998   44       0          127          290          203  24.7        1
# 4999   75       0          124          296          124  32.3        0
#
#       Exercise_Hours  Family_History  Disease
# 0                7.6               1        0
# 1                2.8               0        1
# 2                8.5               0        0
# 3                0.6               1        1
# 4                9.5               0        1
# ...              ...             ...      ...
# 4995             4.1               0        0
# 4996             8.3               0        1
# 4997             7.6               0        0
# 4998             6.8               0        0
# 4999             3.3               0        1
#
# [5000 rows x 10 columns]

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             5000 non-null   int64
#  1   Gender          5000 non-null   int64
#  2   Systolic_BP     5000 non-null   int64
#  3   Cholesterol     5000 non-null   int64
#  4   Blood_Sugar     5000 non-null   int64
#  5   BMI             5000 non-null   float64
#  6   Smoking         5000 non-null   int64
#  7   Exercise_Hours  5000 non-null   float64
#  8   Family_History  5000 non-null   int64
#  9   Disease         5000 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 390.8 KB
#                Age       Gender  Systolic_BP  Cholesterol  Blood_Sugar  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     50.202400     0.498400   135.640200   238.182000   160.520800
# std      17.561136     0.500047    26.313921    64.244215    52.419629
# min      20.000000     0.000000    90.000000   130.000000    70.000000
# 25%      35.000000     0.000000   113.000000   182.000000   115.000000
# 50%      50.000000     0.000000   136.000000   236.000000   160.000000
# 75%      66.000000     1.000000   159.000000   294.000000   206.000000
# max      80.000000     1.000000   180.000000   350.000000   250.000000
#
#                BMI      Smoking  Exercise_Hours  Family_History      Disease
# count  5000.000000  5000.000000     5000.000000     5000.000000  5000.000000
# mean     28.857500     0.311000        5.065080        0.395200     0.400000
# std       6.318293     0.462949        2.872672        0.488943     0.489947
# min      18.000000     0.000000        0.000000        0.000000     0.000000
# 25%      23.400000     0.000000        2.600000        0.000000     0.000000
# 50%      28.800000     0.000000        5.100000        0.000000     0.000000
# 75%      34.200000     1.000000        7.500000        1.000000     1.000000
# max      40.000000     1.000000       10.000000        1.000000     1.000000

# %%
df.isnull().sum()
# Out:
# Age               0
# Gender            0
# Systolic_BP       0
# Cholesterol       0
# Blood_Sugar       0
# BMI               0
# Smoking           0
# Exercise_Hours    0
# Family_History    0
# Disease           0
# dtype: int64

# %%
sns.countplot(
    x="Disease",
    data=df
)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(
    df.corr(),
    annot=True,
    cmap="coolwarm"
)
plt.show()

# %%
X = df.drop("Disease", axis=1)
y = df["Disease"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
